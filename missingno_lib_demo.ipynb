# %% [markdown]
# <a href="https://colab.research.google.com/github/DavidvsData/Udacity-How-to-use-Git-and-Github/blob/master/missingno_lib_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import datetime as dt
import missingno as msno

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Datasets/HRdatav14Modified2.csv')

# %%
df.head()
# Out:
#           Employee_Name  EmpID  MarriedID  MaritalStatusID MaritalDesc  \
# 0  Wallace, Courtney  E  10274          1                1     Married
# 1      Patronick, Lucas  10005          0                0      Single
# 2  Baczenski, Rachael    10252          1                1     Married
# 3      Meads, Elizabeth  10128          0                0      Single
# 4    Tavares, Desiree    10221          1                1     Married
#
#    GenderID  EmpStatusID        EmploymentStatus  DeptID  \
# 0         0            5  Voluntarily Terminated       5
# 1         1            5  Voluntarily Terminated       4
# 2         0            5  Voluntarily Terminated       5
# 3         0            5  Voluntarily Terminated       5
# 4         0            5  Voluntarily Terminated       5
#
#              Department  ...        TermReason      ManagerName  ManagerID  \
# 0     Production         ...  Another position       Janet King          2
# ...

# %%
msno.bar(df)

# %%
msno.heatmap(df, cmap='YlGnBu')

# %%
msno.matrix(df)

# %%
msno.heatmap(df)
